# %% [raw]
# pip install numpy

# %%
import numpy as np

# %% [raw]
# 1. צרי מערך באורך 10 של מספרים שלמים רנדומליים בין 1 ל-50 וחשבי את הממוצע של המספרים

# %%
random_array = np.random.randint(1,51,size=10)
random_array
# Out:
# array([30, 29, 39, 16, 42, 44, 32, 50, 11,  8], dtype=int32)

# %%
np.mean(random_array)
# Out:
# np.float64(30.1)

# %% [raw]
# 2. צרי שני מערכים דו מימדיים בגודל 3, חברי אותם, ובדקי מה הממוצע של התוצאה

# %%
arr1=[[1,2,3],[1,2,3]]
arr2=[[1,2,3],[1,2,3]]
arr3=np.add(arr1 , arr2)
arr3
# Out:
# array([[2, 4, 6],
#        [2, 4, 6]])

# %%
np.mean(arr3)
# Out:
# np.float64(4.0)

# %%
arr4
# Out:
# array([[2, 4, 6],
#        [2, 4, 6]])

# %% [raw]
# 3. צרי מערך של 20 מספרים שלמים רנדומליים בין 1 ל-100. מצאי את כל המספרים שגדולים מ-50 במערך זה.

# %%
random_array2 = np.random.randint(1,101,size=20)
random_array2
# Out:
# array([20, 26, 85, 87, 65, 99, 19, 21, 10, 35, 25, 34, 79, 97, 87, 34, 31,
#        79, 66, 67], dtype=int32)

# %%
greater_than_50 = random_array2[random_array2 > 50]
greater_than_50
# Out:
# array([85, 87, 65, 99, 79, 97, 87, 79, 66, 67], dtype=int32)

# %% [raw]
# 4. צרי מערך של מספרים מ-1 עד 10. ערבבי את המערך ולאחר מכן בחרי באופן אקראי  אלמנטים ממנו

# %%
arr5=np.arange(1, 11)
np.random.shuffle(arr5)
random_elements = np.random.choice(arr, 3, replace=False)
